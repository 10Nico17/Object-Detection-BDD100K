# %%
# !unzip -q "/content/drive/MyDrive/video.zip"
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-27-5de0d3c0859d> in <cell line: 1>()
# ----> 1 get_ipython().system('unzip -q "/content/drive/MyDrive/video.zip"')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# !zip -r content/runs/detect/train TrainingYolov8s
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-10-0604b4398880> in <cell line: 1>()
# ----> 1 get_ipython().system('zip -r content/runs/detect/train TrainingYolov8s')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q "/content/drive/MyDrive/data.zip"

# %%
# !nvidia-smi
# Out:
# Wed Apr 10 12:38:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0              23W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
ROOT_DIR = '/content/drive/MyDrive/'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.6/749.6 kB 10.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
model.info()
# Out:
# Model summary: 225 layers, 3012213 parameters, 0 gradients, 8.2 GFLOPs
# (225, 3012213, 0, 8.2006016)

# %%
print(model)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
## 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "dataset3.yaml"), epochs=15)  # train the model
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 192MB/s]
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Inference Time**

# %%
results = model('/content/data/images/test/fe144fec-22a9e4a4.jpg')
# Out:
# image 1/1 /content/data/images/test/fe144fec-22a9e4a4.jpg: 384x640 5 cars, 1 traffic sign, 120.8ms
# Speed: 1.9ms preprocess, 120.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# **Predict some Random Images**

# %%
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
import os
import random
import cv2
from PIL import Image

# Verzeichnis mit Bildern
images_dir = '/content/data/images/test/'

# Liste der Dateien im Verzeichnis
image_files = os.listdir(images_dir)

# Zufällige Auswahl von fünf Bildern
random_images = random.sample(image_files, 5)

# Für jedes ausgewählte Bild
for image_file in random_images:
    # Pfad zum Bild
    image_path = os.path.join(images_dir, image_file)

    # Laden des Bildes
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Vorhersage mit dem Modell
    results = model(image_path,save=True)
# Out:
# image 1/1 /content/data/images/test/325bf3b3-d7d0e527.jpg: 384x640 7 cars, 4 trucks, 2 traffic lights, 1 traffic sign, 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train3
#
# image 1/1 /content/data/images/test/26124642-1235a1a6.jpg: 384x640 6 cars, 5 traffic lights, 2 traffic signs, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train4
#
# image 1/1 /content/data/images/test/5d007d58-d22366ba.jpg: 384x640 2 pedestrians, 12 cars, 1 traffic light, 3 traffic signs, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train5
#
# image 1/1 /content/data/images/test/0a2c99b4-d68c2338.jpg: 384x640 13 cars, 6 traffic lights, 4 traffic signs, 9.5ms
# ...

# %% [markdown]
# **Train more episodes**

# %%
## 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model2 = YOLO("/content/runs/detect/train/weights/best.pt")  # load pre trained model

# Use the model
results = model2.train(data=os.path.join(ROOT_DIR, "dataset3.yaml"), epochs=15)  # train the model
# Out:
# Ultralytics YOLOv8.1.45 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
results = model2('/content/drive/MyDrive/driveVideo.mov', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1206) /content/drive/MyDrive/driveVideo.mov: 384x640 3 cars, 1 truck, 2 traffic signs, 12.2ms
# video 1/1 (frame 2/1206) /content/drive/MyDrive/driveVideo.mov: 384x640 2 cars, 1 truck, 1 traffic sign, 9.9ms
# video 1/1 (frame 3/1206) /content/drive/MyDrive/driveVideo.mov: 384x640 3 cars, 1 truck, 2 traffic signs, 9.5ms
# ...

# %%
import os
import random
import cv2
from PIL import Image

# Verzeichnis mit Bildern
images_dir = '/content/data/images/test/'

# Liste der Dateien im Verzeichnis
image_files = os.listdir(images_dir)

# Zufällige Auswahl von fünf Bildern
random_images = random.sample(image_files, 10)

# Für jedes ausgewählte Bild
for image_file in random_images:
    # Pfad zum Bild
    image_path = os.path.join(images_dir, image_file)

    # Laden des Bildes
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Vorhersage mit dem Modell
    results = model(image_path,save=True)
# Out:
# image 1/1 /content/data/images/test/325bf3b3-d7d0e527.jpg: 384x640 7 cars, 4 trucks, 2 traffic lights, 1 traffic sign, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train8
#
# image 1/1 /content/data/images/test/26124642-1235a1a6.jpg: 384x640 6 cars, 5 traffic lights, 2 traffic signs, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train9
#
# image 1/1 /content/data/images/test/5d007d58-d22366ba.jpg: 384x640 2 pedestrians, 12 cars, 1 traffic light, 3 traffic signs, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/train10
#
# image 1/1 /content/data/images/test/0a2c99b4-d68c2338.jpg: 384x640 13 cars, 6 traffic lights, 4 traffic signs, 9.3ms
# ...
